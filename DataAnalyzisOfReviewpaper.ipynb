# %% [markdown]
# <a href="https://colab.research.google.com/github/sajad95/Heat/blob/main/DataAnalyzisOfReviewpaper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import DataFrame
from pandas import concat
from numpy import array
from google.colab import drive  
import seaborn as sns   
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('dark')
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_excel('/content/Reviewpaper.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Article Titlewebofscience  493 non-null    object
#  1   Abstractwebofscience       492 non-null    object
#  2   DOIwebofscience            474 non-null    object
#  3   Titlesscopus               336 non-null    object
#  4   Abstractscopus             336 non-null    object
#  5   DOIscopus                  240 non-null    object
#  6   Linkscopus                 336 non-null    object
#  7   Titleoldscopus             161 non-null    object
#  8   DOIoldscopus               152 non-null    object
#  9   Linkoldscopus              161 non-null    object
#  10  Abstractoldscopus          161 non-null    object
# dtypes: object(11)
# memory usage: 42.5+ KB

# %% [markdown]
# Note that this method removes all spaces between the strings, so if you want to keep spaces within the strings but remove spaces at the beginning or end, you can use the str.strip() method instead of str.replace().

# %%
# Print the resulting dataframe
df.head()
# Out:
#                            Article Titlewebofscience  \
# 0  Estimating surface temperature from thermal im...
# 1  Deep learning approaches to building rooftop t...
# 2  Automatic Detection of Linear Thermal Bridges ...
# 3  Introduction of the combination of thermal fun...
# 4  Automatic recognition of earth rock embankment...
#
#                                 Abstractwebofscience  \
# 0  Thermal performance assessment of building(s) ...
# 1  Thermal bridges are weak points of building en...
# 2  Detecting thermal bridges in building envelope...
# 3  Infrastructure inspection is fundamental to ke...
# 4  Leakage erosion is one of the most harmful dri...
#
#                    DOIwebofscience  \
# 0       10.1016/j.jobe.2020.101637
# 1     10.1016/j.autcon.2022.104690
# 2              10.3390/app11030931
# 3    10.1080/17686733.2022.2060545
# 4  10.1016/j.isprsjprs.2022.07.009
#
#                                         Titlesscopus  \
# ...

# %%
# Initialize a new column to store the comparison results
df['Similarity1'] = False

# Loop through each value in column A
for a in df['DOIwebofscience']:
    # Loop through each value in column B
    for b in df['DOIscopus']:
        # Check if the values are similar
        if a == b:
            df.loc[df['DOIwebofscience'] == a, 'Similarity'] = True
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Article Titlewebofscience  493 non-null    object
#  1   Abstractwebofscience       492 non-null    object
#  2   DOIwebofscience            474 non-null    object
#  3   Titlesscopus               336 non-null    object
#  4   Abstractscopus             336 non-null    object
#  5   DOIscopus                  240 non-null    object
#  6   Linkscopus                 336 non-null    object
#  7   Titleoldscopus             161 non-null    object
#  8   DOIoldscopus               152 non-null    object
#  9   Linkoldscopus              161 non-null    object
#  10  Abstractoldscopus          161 non-null    object
#  11  Similarity                 493 non-null    bool
# dtypes: bool(1), object(11)
# memory usage: 43.0+ KB
# ...

# %%
# Initialize a new column to store the comparison results
df['Similarity2'] = False

# Loop through each value in column A
for a in df['DOIscopus']:
    # Loop through each value in column B
    for b in df['DOIoldscopus']:
        # Check if the values are similar
        if a == b:
            df.loc[df['DOIscopus'] == a, 'Similarity'] = True
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Article Titlewebofscience  493 non-null    object
#  1   Abstractwebofscience       492 non-null    object
#  2   DOIwebofscience            474 non-null    object
#  3   Titlesscopus               336 non-null    object
#  4   Abstractscopus             336 non-null    object
#  5   DOIscopus                  240 non-null    object
#  6   Linkscopus                 336 non-null    object
#  7   Titleoldscopus             161 non-null    object
#  8   DOIoldscopus               152 non-null    object
#  9   Linkoldscopus              161 non-null    object
#  10  Abstractoldscopus          161 non-null    object
#  11  Similarity                 493 non-null    bool
#  12  Similarity2                493 non-null    bool
# dtypes: bool(2), object(11)
# ...

# %%
df.to_csv('Reviewpaper.csv', index=False)
