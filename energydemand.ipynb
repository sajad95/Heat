# %% [markdown]
# <a href="https://colab.research.google.com/github/sajad95/Heat/blob/main/energydemand.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 34.1 MB/s
# ...
#      |████████████████████████████████| 15.4 MB 30.2 MB/s
# ...

# %%
import geopandas as gpd
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/saj')
# !pip install mapclassify
# Out:
# Drive already mounted at /content/saj; to attempt to forcibly remount, call drive.mount("/content/saj", force_remount=True).
# ...

# %%
Ab = gpd.read_file('/content/drive/MyDrive/master proj/Ab/AbeGrm.shp')

# %%
Ab.plot()

# %%
print(Ab)
# Out:
#         full_id  ...                                           geometry
# 0    w907652009  ...  POLYGON ((52.19361 35.90596, 52.19361 35.90588...
# 1    w907652010  ...  POLYGON ((52.19288 35.90615, 52.19295 35.90602...
# 2    w907652011  ...  POLYGON ((52.19283 35.90622, 52.19286 35.90617...
# 3    w907652012  ...  POLYGON ((52.19308 35.90578, 52.19297 35.90571...
# 4    w907652018  ...  POLYGON ((52.19342 35.90748, 52.19343 35.90743...
# ..          ...  ...                                                ...
# 193  w913048503  ...  POLYGON ((52.19428 35.90637, 52.19442 35.90635...
# 194  w913048504  ...  POLYGON ((52.19347 35.90678, 52.19347 35.90673...
# 195  w913048505  ...  POLYGON ((52.19279 35.90701, 52.19283 35.90699...
# 196  w913048506  ...  POLYGON ((52.19298 35.90709, 52.19300 35.90704...
# 197  w913048507  ...  POLYGON ((52.19381 35.90654, 52.19382 35.90643...
#
# [198 rows x 7 columns]

# %%
ax = Ab.plot(column='Area',cmap='OrRd',
             figsize=(25,10),legend=True,
             scheme='user_defined',
             classification_kwds={'bins':[0,50,100,150,200,250,300,350,400,500,550,600]},
             edgecolor='black',linewidth=0.4)
